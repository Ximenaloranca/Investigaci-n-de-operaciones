# %% [markdown]
# <a href="https://colab.research.google.com/github/Ximenaloranca/Investigaci-n-de-operaciones/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

# %%
c1, c2, d, h, K, L, Q, Qop, t1=sp.symbols("c1, c2, d, h, K, L, Q, Qop, t1")
T=sp.Function("T")

# %%
c1=3
c2=2.5
d=187.5
h=0.02
K=20
L=2
q=1000
Qop=612.3724

# %%
t1 = Qop/d

# %%
np.floor(L/t1)
# Out:
# np.float64(0.0)

# %% [markdown]
# Aqui va el texto del problema

# %%
def T(Q):
  if Q <= q:
    f=c1*d+K*d/Q+h*Q/2
  else:
    f=c2*d+K*d/Q+h*Q/2
  return f

# %%
T(Qop)
# Out:
# 574.7474487139159

# %%
Q**2 + (2/h)*(c2*d-T(Qop))*Q+2*K*d/h
# Out:
# Q**2 - 10599.7448713916*Q + 375000.0

# %%
eq=sp.Eq(Q**2 + (2/h)*(c2*d*T(Qop)*Q+2*K*d/h),0)

# %%
eq
# Out:
# Eq(Q**2 + 26941286.6584648*Q + 37500000.0, 0)

# %%
sol=sp.solve(eq, Q)

# %%
sol
# Out:
# [-26941285.2665490, -1.39191577643703]

# %%
def Qop(K,d,h):
  return np.sqrt((2*K*d)/h)

# %%
Qop(K,d,h)
# Out:
# np.float64(612.3724356957945)

# %%
def T(Q, c1, c2, h, k, d, q):
  Q = np.array(Q)

  c = np.where(Q <= q, c1, c2)

  return c*d + (K*d)/Q  + (h*Q)/2

# %%
Q_vals = np.linspace(100, 2000, 100)

T_vals = T(Q_vals, c1, c2, h, K, d, q)

plt.plot(Q_vals, T_vals, label="T(Q)")


plt.xlabel("Q")
plt.ylabel("T(Q)")
plt.title("Funcion por partes T(Q)")
plt.legend()
plt.grid(True)
plt.show()
