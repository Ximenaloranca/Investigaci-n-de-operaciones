# %% [markdown]
# <a href="https://colab.research.google.com/github/Ximenaloranca/Investigaci-n-de-operaciones/blob/main/Gr%C3%A1fica_de_redes_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dibujo de redes:🫣**

# %%
import networkx as nx #4 de septiembre 2025

# %%
G=nx.DiGraph() #grafo dirigido
G.add_edge("A","B",capacity=2)
G.add_edge("B","C",capacity=2)
G.add_edge("B","D",capacity=8)
G.add_edge("A","C",capacity=3)
G.add_edge("C","D",capacity=8)

# %%
G
nx.draw_networkx(G)

# %%
nx.nodes(G) #Esta funcion devuelve la lista de nodos que conforman la red
# Out:
# NodeView(('A', 'B', 'C', 'D'))

# %%
nx.edges(G)
# Out:
# OutEdgeView([('A', 'B'), ('A', 'C'), ('B', 'C'), ('B', 'D'), ('C', 'D')])

# %%
nx.number_of_nodes(G)
# Out:
# 4
